# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )
document_tree

# %%
# print names of all countries
for child in document_tree.getroot():
    print (child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print ('* ' + element.find('name').text + ':'),
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print (capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )
document

# %%
root = document.getroot()
root
# Out:
# <Element 'mondial' at 0x1049279a8>

# %%
#Question 1
#create a dictionary with the infant mortality rates of all countries by looping through all countries where infant
#mortality is listed and then use heapq to list the lowest 10

mort_dict = {}
for element in root.iterfind('country'):
    if element.find('infant_mortality') is None:
        pass
    else:
        mort_dict[element.find('name').text] = float(element.find('infant_mortality').text)
        
from heapq import nsmallest
from operator import itemgetter

for country, mortality in nsmallest(10, mort_dict.items(), key=itemgetter(1)):
    print (country, mortality)
# Out:
# Monaco 1.81
# Japan 2.13
# Bermuda 2.48
# Norway 2.48
# Singapore 2.53
# Sweden 2.6
# Czech Republic 2.63
# Hong Kong 2.73
# Macao 3.13
# Iceland 3.15

# %%
#Question 2
#create a dictionary of populations for all cities and then use heapq to list the top ten

city_dict = {}
# print names of all countries and their cities
for element in root.iterfind('country'):
    #print ('* ' + element.find('name').text + ':'),
    capitals_string = ''
    for subelement in element.getiterator('city'):
        if subelement.find('population') is None:
            pass
        else:
            city_dict[subelement.find('name').text] = int(subelement.find('population').text)

from heapq import nlargest
from operator import itemgetter

for city, pop in nlargest(10, city_dict.items(), key=itemgetter(1)):
    print (city, pop)
# Out:
# Seoul 10229262
# Mumbai 9925891
# São Paulo 9412894
# Jakarta 8259266
# Shanghai 8205598
# Ciudad de México 8092449
# Moskva 8010954
# Tokyo 7843000
# Beijing 7362426
# Delhi 7206704

# %%
#Question3 begin by creating a dictionary of the populations of all countries according to the latest population

#the latest population was found by creating a list of all population figure years for each country and selecting 
#the maximum for each

#the maximum year was then used to select a single population value for each country
country_pop_dict = {}
popul = []
for element in root.iterfind('country'):
    max_list=[]
    country = element.find('name').text
    for x in element.iter("population"):
        max_list.append(int(x.attrib['year']))
    pop_year = max(max_list)
    for x in element.iter("population"):
        if int(x.attrib['year']) == pop_year:
            population = x.text
    country_pop_dict[country] = int(population)
country_pop_dict
# Out:
# {'Afghanistan': 26023100,
#  'Albania': 51152,
#  'Algeria': 37062820,
#  'American Samoa': 55519,
#  'Andorra': 22256,
#  'Angola': 965288,
#  'Anguilla': 13037,
#  'Antigua and Barbuda': 22219,
#  'Argentina': 3049229,
#  'Armenia': 1066264,
#  'Aruba': 101484,
#  'Australia': 381488,
#  'Austria': 52100,
#  'Azerbaijan': 290500,
#  'Bahamas': 248948,
#  'Bahrain': 1234596,
#  'Bangladesh': 479837,
#  'Barbados': 88529,
#  'Belarus': 1905475,
#  'Belgium': 97692,
#  'Belize': 53532,
#  'Benin': 9983884,
#  'Bermuda': 64237,
#  'Bhutan': 733004,
#  'Bolivia': 205346,
#  'Bosnia and Herzegovina': 93028,
#  'Botswana': 100079,
#  'Brazil': 2852372,
#  'British Virgin Islands': 23161,
#  'Brunei': 279924,
#  'Bulgaria': 7284552,
#  'Burkina Faso': 17322796,
#  'Burundi': 8444784,
#  'Cambodia': 14364931,
#  'Cameroon': 1384286,
#  'Canada': 35591,
#  'Cape Verde': 131719,
#  'Cayman Islands': 55691,
#  'Central African Republic': 4349921,
#  'Ceuta': 82376,
#  'Chad': 11720781,
#  'Chile': 212813,
#  'China': 29700000,
#  'Christmas Island': 2072,
#  'Cocos Islands': 596,
#  'Colombia': 70260,
#  'Comoros': 683081,
#  'Congo': 829134,
#  'Cook Islands': 17794,
#  'Costa Rica': 428103,
#  'Cote dIvoire': 542082,
#  'Croatia': 70674,
#  'Cuba': 371198,
#  'Curacao': 150563,
#  'Cyprus': 101000,
#  'Czech Republic': 77137,
#  'Denmark': 817907,
#  'Djibouti': 834036,
#  'Dominica': 14725,
#  'Dominican Republic': 591985,
#  'Ecuador': 305632,
#  'Egypt': 83667047,
#  'El Salvador': 126353,
#  'Equatorial Guinea': 696167,
#  'Eritrea': 5741159,
#  'Estonia': 1294455,
#  'Ethiopia': 212665,
#  'Falkland Islands': 2931,
#  'Faroe Islands': 12245,
#  'Fiji': 860559,
#  'Finland': 66415,
#  'France': 145034,
#  'French Guiana': 57229,
#  'French Polynesia': 268270,
#  'Gabon': 1556222,
#  'Gambia': 1882450,
#  'Gaza Strip': 1760037,
#  'Georgia': 4483800,
#  'Germany': 105739,
#  'Ghana': 311206,
#  'Gibraltar': 27495,
#  'Greece': 233,
#  'Greenland': 56370,
#  'Grenada': 103328,
#  'Guadeloupe': 404635,
#  'Guam': 159358,
#  'Guatemala': 232703,
#  'Guernsey': 59807,
#  'Guinea': 194178,
#  'Guinea-Bissau': 1586624,
#  'Guyana': 118363,
#  'Haiti': 9896400,
#  'Holy See': 842,
#  'Honduras': 552100,
#  'Hong Kong': 7071576,
#  'Hungary': 1729040,
#  'Iceland': 17490,
#  'India': 10086292,
#  'Indonesia': 3486432,
#  'Iran': 178020,
#  'Iraq': 1612692,
#  'Ireland': 56779,
#  'Isle of Man': 84497,
#  'Israel': 7420368,
#  'Italy': 123782,
#  'Jamaica': 662426,
#  'Japan': 1415000,
#  'Jersey': 97857,
#  'Jordan': 6249000,
#  'Kazakhstan': 814401,
#  'Kenya': 40909194,
#  'Kiribati': 50182,
#  'Kosovo': 198214,
#  'Kuwait': 637411,
#  'Kyrgyzstan': 265200,
#  'Laos': 6514432,
#  'Latvia': 696618,
#  'Lebanon': 4341092,
#  'Lesotho': 2008921,
#  'Liberia': 3957990,
#  'Libya': 6040612,
#  'Liechtenstein': 5241,
#  'Lithuania': 158891,
#  'Luxembourg': 99852,
#  'Macao': 552503,
#  'Macedonia': 107745,
#  'Madagascar': 21842167,
#  'Malawi': 15013694,
#  'Malaysia': 67964,
#  'Maldives': 133019,
#  'Mali': 13985961,
#  'Malta': 417432,
#  'Marshall Islands': 27797,
#  'Martinique': 392291,
#  'Mauritania': 51026,
#  'Mauritius': 1237091,
#  'Mayotte': 212645,
#  'Melilla': 78476,
#  'Mexico': 8555272,
#  'Micronesia': 102843,
#  'Moldova': 3559541,
#  'Monaco': 36845,
#  'Mongolia': 2754685,
#  'Montenegro': 150977,
#  'Montserrat': 4922,
#  'Morocco': 3157075,
#  'Mozambique': 1194121,
#  'Myanmar': 1158367,
#  'Namibia': 322500,
#  'Nauru': 10025,
#  'Nepal': 204949,
#  'Netherlands': 93726,
#  'New Caledonia': 245580,
#  'New Zealand': 4242048,
#  'Nicaragua': 122924,
#  'Niger': 130707,
#  'Nigeria': 3838160,
#  'Niue': 1611,
#  'Norfolk Island': 2169,
#  'North Korea': 24500520,
#  'Northern Mariana Islands': 53883,
#  'Norway': 74534,
#  'Oman': 3623001,
#  'Pakistan': 173149306,
#  'Palau': 11665,
#  'Panama': 156747,
#  'Papua New Guinea': 318128,
#  'Paraguay': 6672631,
#  'Peru': 477616,
#  'Philippines': 92337852,
#  'Pitcairn': 66,
#  'Poland': 109183,
#  'Portugal': 49578,
#  'Puerto Rico': 157832,
#  'Qatar': 1699435,
#  'Reunion': 145347,
#  'Romania': 388738,
#  'Russia': 491027,
#  'Rwanda': 10515973,
#  'Saint Barthelemy': 9072,
#  'Saint Helena': 5663,
#  'Saint Kitts and Nevis': 52352,
#  'Saint Lucia': 3661,
#  'Saint Martin': 37630,
#  'Saint Pierre and Miquelon': 6312,
#  'Saint Vincent and the Grenadines': 12909,
#  'Samoa': 36735,
#  'San Marino': 4227,
#  'Sao Tome and Principe': 187356,
#  'Saudi Arabia': 791535,
#  'Senegal': 566992,
#  'Serbia': 257867,
#  'Seychelles': 90945,
#  'Sierra Leone': 5751976,
#  'Singapore': 5076700,
#  'Sint Maarten': 37429,
#  'Slovakia': 66358,
#  'Slovenia': 111374,
#  'Solomon Islands': 526447,
#  'Somalia': 9636173,
#  'South Africa': 3740026,
#  'South Korea': 51141463,
#  'South Sudan': 372410,
#  'Spain': 176298,
#  'Sri Lanka': 20263723,
#  'Sudan': 35652002,
#  'Suriname': 240924,
#  'Svalbard': 1872,
#  'Swaziland': 1193148,
#  'Sweden': 140499,
#  'Switzerland': 105676,
#  'Syria': 785000,
#  'Taiwan': 1881645,
#  'Tajikistan': 747500,
#  'Tanzania': 1739530,
#  'Thailand': 65981659,
#  'Timor-Leste': 193563,
#  'Togo': 839566,
#  'Tokelau': 1383,
#  'Tonga': 103252,
#  'Trinidad and Tobago': 1328019,
#  'Tunisia': 10982754,
#  'Turkey': 209255,
#  'Turkmenistan': 5041995,
#  'Turks and Caicos Islands': 31458,
#  'Tuvalu': 9827,
#  'Uganda': 161996,
#  'Ukraine': 340559,
#  'United Arab Emirates': 8441537,
#  'United Kingdom': 1829725,
#  'United States': 658893,
#  'Uruguay': 104011,
#  'Uzbekistan': 2352900,
#  'Vanuatu': 236299,
#  'Venezuela': 352920,
#  'Vietnam': 88772900,
#  'Virgin Islands': 106405,
#  'Wallis and Futuna': 12197,
#  'West Bank': 2790331,
#  'Western Sahara': 554795,
#  'Yemen': 24527000,
#  'Zaire': 62191161,
#  'Zambia': 881524,
#  'Zimbabwe': 356840}

# %%
# A new data structure then creates a dictionary of lists of ethnicities for each country, 
# within the values is a list of dictionaries where the keys are ethnicities and the values 
# are the percentages of ethnicities

ethnic_dict={}
for element in root.iterfind('country'):
    country = element.find('name').text
    l=[]
    if element.find('ethnicgroup') is None:
            pass
    else:
        for x in element.iter("ethnicgroup"):
            e={}
            e[x.text]=float(x.attrib['percentage'])
            l.append(e)
    ethnic_dict[country]=l
ethnic_dict
        
        #popul.append(element.find('population'))
        #for subelement in element.getiterator('e'):
# Out:
# {'Afghanistan': [{'Tajik': 25.0},
#   {'Pashtun': 38.0},
#   {'Uzbek': 6.0},
#   {'Hazara': 19.0}],
#  'Albania': [{'Albanian': 95.0}, {'Greek': 3.0}],
#  'Algeria': [{'European': 1.0}, {'Arab-Berber': 99.0}],
#  'American Samoa': [{'Caucasian': 2.0}, {'Tongan': 4.0}, {'Samoan': 89.0}],
#  'Andorra': [{'Spanish': 43.0},
#   {'Andorran': 33.0},
#   {'Portuguese': 11.0},
#   {'French': 2.0},
#   {'African': 5.0}],
#  'Angola': [{'European': 1.0},
#   {'Ovimbundu': 37.0},
#   {'Kimbundu': 25.0},
#   {'Bakongo': 13.0}],
#  'Anguilla': [{'Black': 90.1}, {'Mulatto': 4.6}, {'White': 3.7}],
#  'Antigua and Barbuda': [],
#  'Argentina': [{'European': 97.0}],
#  'Armenia': [{'Armenian': 97.7}, {'Russian': 0.5}, {'Yezidi': 1.3}],
#  'Aruba': [{'European/Caribbean Amerindian': 80.0}],
#  'Australia': [{'European': 92.0}, {'Asian': 7.0}],
#  'Austria': [{'Austrian': 91.1},
#   {'Turkish': 1.6},
#   {'Slovene': 1.0},
#   {'Croat': 2.0},
#   {'Serbs': 2.0},
#   {'German': 0.9}],
#  'Azerbaijan': [{'Azeri': 90.6},
#   {'Dagestani': 2.2},
#   {'Russian': 1.8},
#   {'Armenian': 1.5}],
#  'Bahamas': [],
#  'Bahrain': [{'Arab': 10.0},
#   {'Asian': 13.0},
#   {'Bahraini': 63.0},
#   {'Iranian': 8.0}],
#  'Bangladesh': [{'Bengali': 98.0}],
#  'Barbados': [{'European': 4.0}, {'African': 80.0}],
#  'Belarus': [{'Belorussian': 81.2},
#   {'Russian': 11.4},
#   {'Polish': 3.9},
#   {'Ukrainian': 2.4}],
#  'Belgium': [{'Fleming': 58.0}, {'Walloon': 31.0}],
#  'Belize': [{'Mestizo': 48.7},
#   {'Creole': 24.9},
#   {'Maya': 10.6},
#   {'Garifuna': 6.1}],
#  'Benin': [{'African': 99.0}],
#  'Bermuda': [{'Black': 54.0}, {'White': 34.1}, {'Mixed': 6.4}],
#  'Bhutan': [{'Bhote': 50.0}, {'Nepalese': 35.0}],
#  'Bolivia': [{'Quechua': 30.0},
#   {'Mestizo': 30.0},
#   {'Aymara': 25.0},
#   {'European': 15.0}],
#  'Bosnia and Herzegovina': [{'Muslim': 48.0},
#   {'Bosniak': 37.1},
#   {'Croat': 14.3}],
#  'Botswana': [{'Batswana': 95.0}, {'Kgalagadi': 4.0}],
#  'Brazil': [{'European': 53.7}, {'Mulatto': 38.5}, {'African': 6.2}],
#  'British Virgin Islands': [{'Black': 83.4},
#   {'White': 7.0},
#   {'Amerindian': 3.4},
#   {'Mixed': 5.4}],
#  'Brunei': [{'Chinese': 20.0}, {'Malay': 64.0}],
#  'Bulgaria': [{'Bulgarian': 76.9},
#   {'Turkish': 8.0},
#   {'Roma': 4.4},
#   {'Macedonian': 2.5},
#   {'Russian': 0.2},
#   {'Armenian': 0.3}],
#  'Burkina Faso': [{'Mossi': 24.0}],
#  'Burundi': [],
#  'Cambodia': [{'Chinese': 1.0}, {'Khmer': 90.0}, {'Vietnamese': 5.0}],
#  'Cameroon': [{'African': 13.0},
#   {'Fulani': 10.0},
#   {'Cameroon Highlanders': 31.0},
#   {'Equatorial Bantu': 19.0},
#   {'Kirdi': 11.0},
#   {'Northwestern Bantu': 8.0},
#   {'Eastern Nigritic': 7.0}],
#  'Canada': [{'British Isles': 28.0},
#   {'French': 23.0},
#   {'European': 15.0},
#   {'Inuit': 2.0}],
#  'Cape Verde': [{'European': 1.0}, {'African': 28.0}, {'Creole': 71.0}],
#  'Cayman Islands': [{'Black': 20.0}, {'White': 20.0}, {'Mixed': 40.0}],
#  'Central African Republic': [{'Baya': 34.0},
#   {'Banda': 27.0},
#   {'Sara': 10.0},
#   {'Mandjia': 21.0},
#   {'Mboum': 4.0},
#   {'MBaka': 4.0}],
#  'Ceuta': [],
#  'Chad': [],
#  'Chile': [{'Amerindian': 3.0}, {'European': 95.0}],
#  'China': [{'Han Chinese': 91.5}],
#  'Christmas Island': [{'Chinese': 70.0}, {'Malay': 10.0}, {'European': 20.0}],
#  'Cocos Islands': [],
#  'Colombia': [{'Mestizo': 58.0},
#   {'European': 20.0},
#   {'Mulatto': 14.0},
#   {'African': 4.0},
#   {'black-Amerindian': 3.0},
#   {'Amerindian': 1.0}],
#  'Comoros': [],
#  'Congo': [],
#  'Cook Islands': [{'Polynesian': 93.5}],
#  'Costa Rica': [{'Mestizo': 74.0},
#   {'European': 20.0},
#   {'African': 3.0},
#   {'Amerindian': 1.0},
#   {'Chinese': 1.0}],
#  'Cote dIvoire': [{'Malinke': 11.0},
#   {'Baoule': 23.0},
#   {'Bete': 18.0},
#   {'Senoufou': 15.0}],
#  'Croatia': [{'Croat': 89.6},
#   {'Serb': 4.5},
#   {'Hungarian': 0.5},
#   {'Muslim': 0.9},
#   {'Slovene': 0.5}],
#  'Cuba': [{'European': 65.1},
#   {'Mestizo': 12.0},
#   {'Mulatto': 12.0},
#   {'African': 10.1}],
#  'Curacao': [],
#  'Cyprus': [{'Greek': 77.0}, {'Turkish': 18.0}],
#  'Czech Republic': [{'Czech': 90.4},
#   {'Moravian': 3.7},
#   {'Slovak': 1.9},
#   {'German': 0.5},
#   {'Polish': 0.6},
#   {'Roma': 0.3},
#   {'Hungarian': 0.2}],
#  'Denmark': [],
#  'Djibouti': [{'Italian': 5.0}, {'Afar': 35.0}, {'Somali': 60.0}],
#  'Dominica': [{'Carib Indians': 100.0}],
#  'Dominican Republic': [{'Mulatto': 73.0},
#   {'European': 16.0},
#   {'African': 11.0}],
#  'Ecuador': [{'Mestizo': 65.0},
#   {'Amerindian': 25.0},
#   {'European': 7.0},
#   {'African': 3.0}],
#  'Egypt': [{'European': 1.0}, {'Eastern Hamitic': 99.0}],
#  'El Salvador': [{'Mestizo': 90.0}, {'European': 9.0}, {'Amerindian': 1.0}],
#  'Equatorial Guinea': [],
#  'Eritrea': [{'Tigrinya': 55.0},
#   {'Tigre': 30.0},
#   {'Saho': 4.0},
#   {'Kunama': 2.0},
#   {'Rashaida': 2.0},
#   {'Bilen': 2.0}],
#  'Estonia': [{'Estonian': 68.7},
#   {'Russian': 25.6},
#   {'Ukrainian': 2.1},
#   {'Belorussian': 1.2},
#   {'Finn': 0.8}],
#  'Ethiopia': [{'Oromo': 34.5},
#   {'Amhara': 26.9},
#   {'Somali': 6.2},
#   {'Tigraway': 6.1},
#   {'Sidama': 4.0},
#   {'Gurage': 2.5},
#   {'Welaita': 2.3},
#   {'Hadiya': 1.7},
#   {'Afar': 1.7}],
#  'Falkland Islands': [{'Christian': 67.2}, {'None': 31.5}],
#  'Faroe Islands': [{'Scandinavian': 100.0}],
#  'Fiji': [{'Indian': 46.0}, {'Fijian': 49.0}],
#  'Finland': [{'Finn': 93.4},
#   {'Swede': 5.6},
#   {'Russian': 0.5},
#   {'Estonian': 0.3}],
#  'France': [],
#  'French Guiana': [{'Amerindian': 12.0}],
#  'French Polynesia': [{'French': 10.0},
#   {'Chinese': 12.0},
#   {'Polynesian': 78.0}],
#  'Gabon': [],
#  'Gambia': [{'African': 99.0}],
#  'Gaza Strip': [{'Jewish': 0.6}, {'Palestinian Arab': 99.4}],
#  'Georgia': [{'Georgian': 83.8}, {'Azeri': 6.5}, {'Russian': 1.5}],
#  'Germany': [{'German': 91.5}, {'Turkish': 2.4}],
#  'Ghana': [{'European': 0.2}, {'African': 99.8}],
#  'Gibraltar': [],
#  'Greece': [{'Greek': 93.0}],
#  'Greenland': [{'Danish': 14.0}, {'Greenlander': 86.0}],
#  'Grenada': [{'African': 100.0}],
#  'Guadeloupe': [{'Chinese': 5.0}],
#  'Guam': [{'Chamorro': 37.1}, {'Filipino': 26.3}],
#  'Guatemala': [{'Mestizo': 50.0}, {'European': 10.0}, {'Amerindian': 30.5}],
#  'Guernsey': [{'Norman-French': 100.0}],
#  'Guinea': [{'Malinke': 30.0}, {'Peuhl': 40.0}, {'Soussou': 20.0}],
#  'Guinea-Bissau': [{'European': 1.0}, {'African': 99.0}],
#  'Guyana': [{'East Indian': 43.5}, {'African': 30.2}, {'Amerindian': 9.1}],
#  'Haiti': [{'African': 95.0}, {'Mulatto': 3.0}, {'European': 2.0}],
#  'Holy See': [],
#  'Honduras': [{'Mestizo': 90.0},
#   {'Amerindian': 7.0},
#   {'African': 2.0},
#   {'European': 1.0}],
#  'Hong Kong': [{'Chinese': 95.0}, {'Filipino': 1.6}, {'Indonesian': 1.3}],
#  'Hungary': [{'Hungarian': 92.3},
#   {'Roma': 1.9},
#   {'Serb': 2.0},
#   {'German': 2.6},
#   {'Slovak': 0.8},
#   {'Romanian': 0.7}],
#  'Iceland': [{'Celt': 100.0}],
#  'India': [{'Dravidian': 25.0}, {'Indo-Aryan': 72.0}, {'Mongol': 3.0}],
#  'Indonesia': [{'Javanese': 45.0},
#   {'Sundanese': 14.0},
#   {'Madurese': 7.5},
#   {'Malay': 7.5}],
#  'Iran': [{'Arab': 3.0},
#   {'Persian': 51.0},
#   {'Baloch': 2.0},
#   {'Azerbaijani': 24.0},
#   {'Kurd': 7.0},
#   {'Lur': 2.0},
#   {'Turkmen': 2.0},
#   {'Gilaki Mazandarani': 8.0}],
#  'Iraq': [{'Kurdish': 15.0}, {'Arab': 75.0}, {'Assyrian': 5.0}],
#  'Ireland': [{'Irish': 87.4}, {'Asian': 1.3}, {'African': 1.1}],
#  'Isle of Man': [],
#  'Israel': [{'Jewish': 76.4}, {'Arab': 23.0}],
#  'Italy': [],
#  'Jamaica': [{'African': 76.3},
#   {'Afro-European': 15.1},
#   {'Afro-East Indian': 3.0},
#   {'Afro-Chinese': 1.2}],
#  'Japan': [{'Japanese': 99.4}],
#  'Jersey': [{'Norman-French': 100.0}],
#  'Jordan': [{'Armenian': 1.0}, {'Arab': 98.0}, {'Circassian': 1.0}],
#  'Kazakhstan': [{'Kazakh': 63.1},
#   {'Russian': 23.7},
#   {'Uzbek': 2.8},
#   {'Ukrainian': 2.1},
#   {'Uighur': 1.4},
#   {'Tatar': 1.3},
#   {'German': 1.1}],
#  'Kenya': [{'Arab': 1.0},
#   {'Kikuyu': 22.0},
#   {'Luhya': 14.0},
#   {'Luo': 13.0},
#   {'Kalenjin': 12.0},
#   {'Kamba': 11.0},
#   {'Kisii': 6.0},
#   {'Meru': 6.0}],
#  'Kiribati': [{'Micronesian': 100.0}],
#  'Kosovo': [{'Albanian': 92.0}, {'Serbian': 5.0}],
#  'Kuwait': [{'Arab': 35.0},
#   {'Iranian': 4.0},
#   {'South Asian': 9.0},
#   {'Kuwaiti': 45.0}],
#  'Kyrgyzstan': [{'Kyrgyz': 64.9},
#   {'Uzbek': 13.8},
#   {'Russian': 12.5},
#   {'Dungan': 1.1},
#   {'Ukrainian': 1.0},
#   {'Uighur': 1.0}],
#  'Laos': [{'Lao Loum': 68.0},
#   {'Lao Theung': 22.0},
#   {'Lao Soung Hmong Yao': 9.0},
#   {'Vietnamese/Chinese': 1.0}],
#  'Latvia': [{'Latvian': 59.3},
#   {'Russian': 27.8},
#   {'Belorussian': 3.6},
#   {'Ukrainian': 2.5},
#   {'Polish': 2.4},
#   {'Lithuanian': 1.3}],
#  'Lebanon': [{'Armenian': 4.0}, {'Arab': 95.0}],
#  'Lesotho': [{'Sotho': 99.7}],
#  'Liberia': [{'African': 95.0}, {'Americo-Liberians': 5.0}],
#  'Libya': [{'Berber Arab': 97.0}],
#  'Liechtenstein': [{'Italian': 5.0}, {'Alemannic': 95.0}],
#  'Lithuania': [{'Lithuanian': 84.0},
#   {'Polish': 6.1},
#   {'Russian': 4.9},
#   {'Belorussian': 1.1}],
#  'Luxembourg': [{'Luxembourgish': 63.1},
#   {'Portuguese': 13.3},
#   {'French': 4.5},
#   {'Italian': 4.3},
#   {'German': 2.3}],
#  'Macao': [{'Chinese': 95.0}, {'Portuguese': 3.0}],
#  'Macedonia': [{'Macedonian': 64.2},
#   {'Albanian': 25.2},
#   {'Turkish': 3.9},
#   {'Gypsy': 2.7},
#   {'Serb': 1.8}],
#  'Madagascar': [],
#  'Malawi': [],
#  'Malaysia': [{'Malay': 50.4},
#   {'Chinese': 23.7},
#   {'Indian': 7.1},
#   {'Borneo indigenous': 11.0}],
#  'Maldives': [],
#  'Mali': [{'Mande': 50.0},
#   {'Peuhl': 17.0},
#   {'Voltaic': 12.0},
#   {'Songhai': 6.0},
#   {'Tuareg': 10.0}],
#  'Malta': [],
#  'Marshall Islands': [{'Micronesian': 100.0}],
#  'Martinique': [{'Chinese': 5.0}, {'African-white-Indian': 90.0}],
#  'Mauritania': [{'Maur': 30.0}, {'Black Maur': 40.0}],
#  'Mauritius': [{'Creole': 27.0},
#   {'Indo-Mauritian': 68.0},
#   {'Sino-Mauritian': 3.0},
#   {'Franco-Mauritian': 2.0}],
#  'Mayotte': [],
#  'Melilla': [],
#  'Mexico': [{'Mestizo': 60.0}, {'Amerindian': 30.0}, {'European': 9.0}],
#  'Micronesia': [{'Polynesian': 100.0}],
#  'Moldova': [{'Moldavian/Romanian': 78.2},
#   {'Ukrainian': 8.4},
#   {'Russian': 5.8},
#   {'Gagauz': 4.4},
#   {'Bulgarian': 1.9}],
#  'Monaco': [{'French': 47.0}, {'Monegasque': 21.6}, {'Italian': 19.0}],
#  'Mongolia': [{'Mongol': 94.9}, {'Kazak': 5.0}],
#  'Montenegro': [{'Montenegrin': 43.0},
#   {'Serb': 32.0},
#   {'Bosniak': 8.0},
#   {'Albanian': 5.0}],
#  'Montserrat': [],
#  'Morocco': [{'Jewish': 0.2}, {'Arab-Berber': 99.1}],
#  'Mozambique': [{'European': 0.06}, {'Indian': 0.08}, {'Euro-African': 0.2}],
#  'Myanmar': [{'Indian': 2.0},
#   {'Chinese': 3.0},
#   {'Burman': 68.0},
#   {'Shan': 9.0},
#   {'Karen': 7.0},
#   {'Rakhine': 4.0},
#   {'Mon': 2.0}],
#  'Namibia': [],
#  'Nauru': [{'Chinese': 8.0},
#   {'European': 8.0},
#   {'Nauruan': 58.0},
#   {'Pacific Islander': 26.0}],
#  'Nepal': [],
#  'Netherlands': [{'Dutch': 80.7},
#   {'Indonesian': 2.4},
#   {'Turkish': 2.2},
#   {'Moroccan': 2.0},
#   {'Surinamese': 2.0},
#   {'Caribbean': 0.8}],
#  'New Caledonia': [{'Vietnamese': 1.4},
#   {'European': 34.1},
#   {'Melanesian': 44.1},
#   {'Wallisian': 9.0},
#   {'Indonesian': 2.5}],
#  'New Zealand': [{'European': 56.8},
#   {'Asian': 8.0},
#   {'Maori': 7.4},
#   {'Pacific Islander': 4.6}],
#  'Nicaragua': [{'Mestizo': 69.0},
#   {'European': 17.0},
#   {'African': 9.0},
#   {'Amerindian': 5.0}],
#  'Niger': [{'Fula': 8.5},
#   {'Hausa': 56.0},
#   {'Djerma': 22.0},
#   {'Tuareg': 8.0},
#   {'Beri Beri': 4.3},
#   {'Gourmantche': 1.2}],
#  'Nigeria': [{'African': 99.0}],
#  'Niue': [{'Polynesian': 100.0}],
#  'Norfolk Island': [],
#  'North Korea': [],
#  'Northern Mariana Islands': [{'Asian': 56.3},
#   {'Pacific Islander': 36.3},
#   {'Caucasian': 1.8}],
#  'Norway': [{'Norwegian': 82.5}, {'Sami': 1.5}],
#  'Oman': [],
#  'Pakistan': [],
#  'Palau': [],
#  'Panama': [{'Mestizo': 84.0}, {'European': 10.0}, {'Amerindian': 6.0}],
#  'Papua New Guinea': [],
#  'Paraguay': [{'Mestizo': 95.0}],
#  'Peru': [{'Amerindian': 45.0}, {'Mestizo': 37.0}, {'European': 15.0}],
#  'Philippines': [{'Chinese': 1.5}, {'Malay': 95.5}],
#  'Pitcairn': [{'Bounty': 100.0}],
#  'Poland': [{'German': 1.3},
#   {'Polish': 97.6},
#   {'Ukrainian': 0.6},
#   {'Byelorussian': 0.5}],
#  'Portugal': [],
#  'Puerto Rico': [{'White': 80.2},
#   {'Black': 8.0},
#   {'Amerindian': 0.4},
#   {'Asian': 0.4}],
#  'Qatar': [{'Indian': 18.0},
#   {'Pakistani': 18.0},
#   {'Arab': 40.0},
#   {'Iranian': 10.0}],
#  'Reunion': [],
#  'Romania': [{'Romanian': 89.1},
#   {'Hungarian': 6.6},
#   {'Roma': 2.5},
#   {'German': 0.3},
#   {'Ukrainian': 0.3},
#   {'Russian': 0.2},
#   {'Turkish': 0.2}],
#  'Russia': [{'Russian': 79.8},
#   {'Tatar': 3.8},
#   {'Ukrainian': 2.0},
#   {'Bashkir': 1.2},
#   {'Chuvash': 1.1}],
#  'Rwanda': [{'Hutu': 80.0}, {'Tutsi': 19.0}, {'Twa': 1.0}],
#  'Saint Barthelemy': [],
#  'Saint Helena': [{'African descent': 50.0},
#   {'White': 25.0},
#   {'Chinese': 25.0}],
#  'Saint Kitts and Nevis': [{'African': 100.0}],
#  'Saint Lucia': [{'African': 90.3}, {'East Indian': 3.2}],
#  'Saint Martin': [],
#  'Saint Pierre and Miquelon': [{'Basques Bretons': 100.0}],
#  'Saint Vincent and the Grenadines': [],
#  'Samoa': [{'Europeans': 0.4}, {'Samoan': 92.6}, {'Euronesians': 7.0}],
#  'San Marino': [],
#  'Sao Tome and Principe': [{'European': 100.0}],
#  'Saudi Arabia': [{'Arab': 90.0}, {'Afro-Asian': 10.0}],
#  'Senegal': [{'Fulani': 17.0},
#   {'Wolof': 36.0},
#   {'Diola': 9.0},
#   {'Mandingo': 9.0},
#   {'Serer': 17.0},
#   {'Toucouleur': 9.0},
#   {'European Lebanese': 1.0}],
#  'Serbia': [{'Serb': 82.9},
#   {'Montenegrin': 0.9},
#   {'Hungarian': 3.9},
#   {'Roma': 1.4},
#   {'Bosniak': 1.8},
#   {'Croat': 1.1}],
#  'Seychelles': [{'Seychellois': 100.0}],
#  'Sierra Leone': [{'Asian': 1.0}, {'African': 99.0}],
#  'Singapore': [{'Indian': 6.4}, {'Chinese': 76.4}, {'Malay': 14.9}],
#  'Sint Maarten': [],
#  'Slovakia': [{'Slovak': 85.7},
#   {'Hungarian': 9.7},
#   {'Roma': 1.7},
#   {'Czech': 1.0},
#   {'Ukrainian': 0.3},
#   {'Ruthenian': 0.3},
#   {'German': 0.1},
#   {'Polish': 0.1}],
#  'Slovenia': [{'Slovene': 91.0},
#   {'Croat': 3.0},
#   {'Serb': 2.0},
#   {'Bosniak': 1.0}],
#  'Solomon Islands': [{'Chinese': 0.3},
#   {'European': 0.8},
#   {'Polynesian': 4.0},
#   {'Micronesian': 1.5},
#   {'Melanesian': 93.0}],
#  'Somalia': [{'Somali': 85.0}],
#  'South Africa': [{'Indian': 2.6}, {'Colored': 8.6}],
#  'South Korea': [],
#  'South Sudan': [],
#  'Spain': [{'Mediterranean Nordic': 100.0}],
#  'Sri Lanka': [{'Sinhalese': 74.0},
#   {'Tamil': 18.0},
#   {'Arab': 7.0},
#   {'Vedda': 1.0}],
#  'Sudan': [{'Arab': 70.0}, {'Beja': 6.0}],
#  'Suriname': [{'Hindustani': 37.0},
#   {'Creole': 31.0},
#   {'Javanese': 15.3},
#   {'African': 10.0},
#   {'Chinese': 2.0},
#   {'Amerindian': 2.0},
#   {'Europeans': 1.0}],
#  'Svalbard': [{'Norwegian': 55.4}, {'Russian Ukrainian': 44.3}],
#  'Swaziland': [{'European': 3.0}, {'African': 97.0}],
#  'Sweden': [{'Swede': 83.0}, {'Finn': 5.0}],
#  'Switzerland': [{'German': 65.0},
#   {'French': 18.0},
#   {'Italian': 10.0},
#   {'Romansch': 1.0}],
#  'Syria': [{'Arab': 90.3}],
#  'Taiwan': [{'Chinese': 14.0}, {'Taiwanese': 84.0}],
#  'Tajikistan': [{'Tajik': 79.9},
#   {'Uzbek': 15.3},
#   {'Russian': 1.1},
#   {'Kyrgyz': 1.1}],
#  'Tanzania': [{'Bantu': 95.0}],
#  'Thailand': [{'Chinese': 14.0}, {'Thai': 75.0}],
#  'Timor-Leste': [],
#  'Togo': [{'African': 99.0}, {'European Syrian-Lebanese': 1.0}],
#  'Tokelau': [{'Polynesian': 95.0}],
#  'Tonga': [],
#  'Trinidad and Tobago': [{'Chinese': 1.0}, {'East Indian': 40.0}],
#  'Tunisia': [{'Jewish': 1.0}, {'European': 1.0}, {'Arab-Berber': 98.0}],
#  'Turkey': [{'Turkish': 84.54}, {'Kurdish': 11.97}, {'Arabic': 1.38}],
#  'Turkmenistan': [{'Turkmen': 85.0}, {'Uzbek': 5.0}, {'Russian': 4.0}],
#  'Turks and Caicos Islands': [{'African': 90.0}],
#  'Tuvalu': [{'Polynesian': 96.0}],
#  'Uganda': [{'Rwanda': 6.0},
#   {'Arab': 1.0},
#   {'Baganda': 17.0},
#   {'Karamojong': 12.0},
#   {'Basogo': 8.0},
#   {'Iteso': 8.0},
#   {'Langi': 6.0},
#   {'Bagisu': 5.0},
#   {'Acholi': 4.0},
#   {'Lugbara': 4.0},
#   {'Bunyoro': 3.0},
#   {'Batobo': 3.0}],
#  'Ukraine': [{'Ukrainian': 77.8},
#   {'Russian': 17.3},
#   {'Belorussian': 0.6},
#   {'Moldovan': 0.5},
#   {'Crimean Tatar': 0.5},
#   {'Bulgarian': 0.4},
#   {'Hungarian': 0.3},
#   {'Romanian': 0.3},
#   {'Polish': 0.3},
#   {'Jewish': 0.2}],
#  'United Arab Emirates': [{'South Asian': 50.0},
#   {'Emiri': 19.0},
#   {'Arab Iranian': 23.0}],
#  'United Kingdom': [{'English': 83.6},
#   {'Scottish': 8.6},
#   {'Welsh': 4.9},
#   {'Northern Irish': 2.9},
#   {'African': 2.0},
#   {'Indian': 1.8},
#   {'Pakistani': 1.3}],
#  'United States': [{'European': 79.96},
#   {'African': 12.85},
#   {'Asian': 4.43},
#   {'Amerindian': 0.97}],
#  'Uruguay': [{'European': 88.0}, {'Mestizo': 8.0}, {'African': 4.0}],
#  'Uzbekistan': [{'Uzbek': 80.0},
#   {'Russian': 5.5},
#   {'Tajik': 5.0},
#   {'Kazak': 3.0},
#   {'Karakalpak': 2.5},
#   {'Tatar': 1.5}],
#  'Vanuatu': [{'French': 4.0}, {'Melanesian': 94.0}],
#  'Venezuela': [],
#  'Vietnam': [{'Viet/Kinh': 85.7},
#   {'Tay': 1.9},
#   {'Thai': 1.8},
#   {'Muong': 1.5},
#   {'Khmer': 1.5},
#   {'Mong': 1.2},
#   {'Nung': 1.1}],
#  'Virgin Islands': [],
#  'Wallis and Futuna': [{'Polynesian': 100.0}],
#  'West Bank': [{'Jewish': 17.0}, {'Palestinian Arab': 83.0}],
#  'Western Sahara': [],
#  'Yemen': [],
#  'Zaire': [{'Mangbetu-Azande': 45.0}],
#  'Zambia': [{'European': 1.1}, {'African': 98.7}],
#  'Zimbabwe': [{'Asian': 1.0}, {'African': 98.0}]}

# %%
# for each ethnicity in each country the percentage ethnicity is multiplied by the the population of that country
# unheap then lists the top ten ethnicities from the resulting dictionary of all with their associated total populations

ethnic_pop_dict={}
for country, list in ethnic_dict.items():
    for ethnicity in list:
        for ethnicity_name, percentage in ethnicity.items():
            if ethnicity_name in ethnic_pop_dict:
                ethnic_pop_dict[ethnicity_name] += int(percentage*country_pop_dict[country]/100)
            else:
                ethnic_pop_dict[ethnicity_name] = int(percentage*country_pop_dict[country]/100)

from heapq import nlargest
from operator import itemgetter

for ethnicity, pop in nlargest(10, ethnic_pop_dict.items(), key=itemgetter(1)):
    print (ethnicity, pop)
# Out:
# Malay 89414169
# Eastern Hamitic 82830376
# Viet/Kinh 76078375
# Thai 51084156
# Arab-Berber 50583950
# Arab 42402733
# African 40986968
# Mangbetu-Azande 27986022
# Han Chinese 27175500
# Chinese 22357554

# %%
#Question 4 first create a dictionary of country codes with their associated country name
country_code_dict={}
for element in root.iterfind('country'):
    code = element.attrib['car_code']
    name = element.find('name').text
    country_code_dict[code]=name

# %%
# create a finder function which creates two dictionaries, one of the locations of the item type
# and another that lists the location of each item

def find_stuff(type, metric, location_type):
    metric_dict={}
    location_dict={}
    for element in root.iterfind(type):
        if element.find(metric) is None:
            pass
        elif element.find(location_type) is None:
            pass
        else:
            location = element.find(location_type).attrib['country']
            name = element.find('name').text
            size = float(element.find(metric).text)
            metric_dict[name]=size
            location_dict[name]=location
            
    #pick the biggest thing

    max_name = max(metric_dict, key=metric_dict.get)
    
    #display the biggest thing, its size and its location
        
    max_dict = {
    'name': max_name,
     metric : metric_dict[max_name],
     location_type: country_code_dict[location_dict[max_name]]
    }
    return max_dict

# %%
#4a
longest_river = str(find_stuff('river', 'length', 'source'))
print('longest river: ' + longest_river)
# Out:
# longest river: {'name': 'Amazonas', 'source': 'Peru', 'length': 6448.0}

# %%
#4b
biggest_lake = str(find_stuff('lake', 'area', 'located'))
print('biggest lake: ' + biggest_lake)
# Out:
# biggest lake: {'name': 'Caspian Sea', 'located': 'Russia', 'area': 386400.0}

# %%
#4c

#had trouble getting the finder function to work for airports so I rewrote the code a little to make it work

elevation_dict={}
location_dict={}
for element in root.iterfind('airport'):
    if element.find('elevation').text is None:
        pass
    else:
        location = element.attrib['country']
        name = element.find('name').text
        size = float(element.find('elevation').text)
        elevation_dict[name]=size
        location_dict[name]=location

location_dict
elevation_dict

max_name = max(elevation_dict, key=elevation_dict.get)

max_dict = {
'name': max_name,
'elevation' : elevation_dict[max_name],
'location': country_code_dict[location_dict[max_name]]
}

highest_airport = str(max_dict)
    
print('the highest airport is: ' + highest_airport)
# Out:
# the highest airport is: {'location': 'Bolivia', 'name': 'El Alto Intl', 'elevation': 4063.0}
